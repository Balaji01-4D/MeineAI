# %%
from spacy import load
from spacy.tokens import DocBin
nlp = load('/home/balaji/MeineAI/FINALMODEL/model-best')
docbin = DocBin()

# %%
 
data = [("move the c:/home/documents/workflow to /backup/plans",{"entities":[(0,4,"ACTION"),(9,35,"FOLDER"),(36,52,"DESTINATION")]}),("mv the /pictures/vacation/beach.jpg to /albums/travel",{"entities":[(0,2,"ACTION"),(7,35,"FILE"),(36,53,"DESTINATION")]}),("c d:/temp/config/settings.json to /configs/system",{"entities":[(0,1,"ACTION"),(2,30,"FILE"),(31,49,"DESTINATION")]}),("move the c:/projects/research/data.csv to /resources/database",{"entities":[(0,4,"ACTION"),(9,38,"FILE"),(39,61,"DESTINATION")]}),("mv the /docs/manuals/user_guide.pdf to /library/guides",{"entities":[(0,2,"ACTION"),(7,35,"FILE"),(36,54,"DESTINATION")]}),("c temp/cache/errors.log to /archives/errors",{"entities":[(0,1,"ACTION"),(2,23,"FILE"),(24,43,"DESTINATION")]}),("move the c:/users/admin/notes/meeting.txt to /documents/minutes",{"entities":[(0,4,"ACTION"),(9,41,"FILE"),(42,63,"DESTINATION")]}),("mv the /images/nature/forest.png to /gallery/photos",{"entities":[(0,2,"ACTION"),(7,32,"FILE"),(33,51,"DESTINATION")]}),("c d:/temp/logs/debug.log to /logs/archives",{"entities":[(0,1,"ACTION"),(2,24,"FILE"),(25,42,"DESTINATION")]}),("move the c:/desktop/assignments/project1 to /backup/projects",{"entities":[(0,4,"ACTION"),(9,40,"FOLDER"),(41,60,"DESTINATION")]}),("mv the /reports/sales/q1.pdf to /library/sales",{"entities":[(0,2,"ACTION"),(7,28,"FILE"),(29,46,"DESTINATION")]}),("c d:/users/public/config.ini to /configs/shared",{"entities":[(0,1,"ACTION"),(2,28,"FILE"),(29,47,"DESTINATION")]}),("move the c:/media/music/track.mp3 to /audio/collection",{"entities":[(0,4,"ACTION"),(9,33,"FILE"),(34,54,"DESTINATION")]}),("mv the /videos/movies/action.mp4 to /media/films",{"entities":[(0,2,"ACTION"),(7,32,"FILE"),(33,48,"DESTINATION")]}),("c temp/data/summary.txt to /resources/archives",{"entities":[(0,1,"ACTION"),(2,23,"FILE"),(24,46,"DESTINATION")]}),("move the c:/configs/server/settings.xml to /configs/backup",{"entities":[(0,4,"ACTION"),(9,39,"FILE"),(40,58,"DESTINATION")]}),("mv the /backup/system/logs/errors.txt to /logs/archive",{"entities":[(0,2,"ACTION"),(7,37,"FILE"),(38,54,"DESTINATION")]}),("c d:/workspace/models/output.h5 to /resources/training",{"entities":[(0,1,"ACTION"),(2,31,"FILE"),(32,54,"DESTINATION")]}),("move the c:/home/documents/reports/weekly.docx to /reports/archive",{"entities":[(0,4,"ACTION"),(9,46,"FILE"),(47,66,"DESTINATION")]}),("mv the /users/admin/photos/trip.jpg to /gallery/vacation",{"entities":[(0,2,"ACTION"),(7,35,"FILE"),(36,56,"DESTINATION")]}),("move the c:/resources/training/data.json to /datasets/final",{"entities":[(0,4,"ACTION"),(9,40,"FILE"),(41,59,"DESTINATION")]}),("mv the /configs/templates/template1.docx to /library/templates",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,62,"DESTINATION")]}),("c d:/users/admin/projects/sample to /resources/examples",{"entities":[(0,1,"ACTION"),(2,32,"FOLDER"),(33,55,"FOLDER")]}),("move the c:/images/screenshot.png to /gallery/screenshots",{"entities":[(0,4,"ACTION"),(9,33,"FILE"),(34,57,"DESTINATION")]}),("mv the /docs/ebooks/book.pdf to /library/reading",{"entities":[(0,2,"ACTION"),(7,28,"FILE"),(29,48,"DESTINATION")]}),("c temp/logs/cache.log to /backup/cache",{"entities":[(0,1,"ACTION"),(2,21,"FILE"),(22,38,"DESTINATION")]}),("delete c:/music/classical/symphony",{"entities":[(0,6,"ACTION"),(7,34,"FOLDER")]}),("rm /videos/genres/comedy",{"entities":[(0,2,"ACTION"),(3,24,"FOLDER")]}),("remove /audio/albums/rock",{"entities":[(0,6,"ACTION"),(7,25,"FOLDER")]}),("del the /pictures/autumn.jpg",{"entities":[(0,3,"ACTION"),(8,28,"FILE")]}),("create the app.js",{"entities":[(0,6,"ACTION"),(11,17,"FILE")]}),("mk the file theme.css",{"entities":[(0,2,"ACTION"),(7,21,"FILE")]}),("mkdir /configs/network",{"entities":[(0,5,"ACTION"),(6,22,"FOLDER")]}),("create the server.rb",{"entities":[(0,6,"ACTION"),(11,20,"FILE")]}),("create the file analytics.ipynb",{"entities":[(0,6,"ACTION"),(11,31,"FILE")]}),("create the api/main.go",{"entities":[(0,6,"ACTION"),(11,22,"FILE")]}),("create the file settings.json",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("mk /projects/ml/models/model.h5",{"entities":[(0,2,"ACTION"),(3,31,"FILE")]}),("create the utils.ts",{"entities":[(0,6,"ACTION"),(11,19,"FILE")]}),("create the app/controllers.py",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("mkdir /media/photos/landscapes",{"entities":[(0,5,"ACTION"),(6,30,"FOLDER")]}),("create the file user_data.sql",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("move the c:/media/music/track.mp3 to /audio/collection",{"entities":[(0,4,"ACTION"),(9,33,"FILE"),(34,54,"DESTINATION")]}),("cp the /videos/movies/action.mp4 to /media/films",{"entities":[(0,2,"ACTION"),(7,32,"FILE"),(33,48,"DESTINATION")]}),("c temp/data/summary.txt to /resources/archives",{"entities":[(0,1,"ACTION"),(2,23,"FILE"),(24,46,"DESTINATION")]}),("move the c:/configs/server/settings.xml to /configs/backup",{"entities":[(0,4,"ACTION"),(9,39,"FILE"),(40,58,"DESTINATION")]}),("cp the /backup/system/logs/errors.txt to /logs/archive",{"entities":[(0,2,"ACTION"),(7,37,"FILE"),(38,54,"DESTINATION")]}),("c d:/workspace/models/output.h5 to /resources/training",{"entities":[(0,1,"ACTION"),(2,31,"FILE"),(32,54,"DESTINATION")]}),("move the c:/home/documents/reports/weekly.docx to /reports/archive",{"entities":[(0,4,"ACTION"),(9,46,"FILE"),(47,66,"DESTINATION")]}),("cp the /users/admin/photos/trip.jpg to /gallery/vacation",{"entities":[(0,2,"ACTION"),(7,35,"FILE"),(36,56,"DESTINATION")]}),("move the c:/resources/training/data.json to /datasets/final",{"entities":[(0,4,"ACTION"),(9,40,"FILE"),(41,59,"DESTINATION")]}),("cp the /configs/templates/template1.docx to /library/templates",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,62,"DESTINATION")]}),("c d:/users/admin/projects/sample to /resources/examples",{"entities":[(0,1,"ACTION"),(2,32,"FOLDER"),(33,55,"DESTINATION")]}),("move the c:/images/screenshot.png to /gallery/screenshots",{"entities":[(0,4,"ACTION"),(9,33,"FILE"),(34,57,"DESTINATION")]}),("move the c:/downloads/music/album.zip to /audio/archives",{"entities":[(0,4,"ACTION"),(9,37,"FILE"),(38,56,"DESTINATION")]}),("cp the /videos/documentaries/nature.mp4 to /media/documentaries",{"entities":[(0,2,"ACTION"),(7,39,"FILE"),(40,63,"DESTINATION")]}),("c temp/data/overview.txt to /resources/archives",{"entities":[(0,1,"ACTION"),(2,24,"FILE"),(25,47,"DESTINATION")]}),("cp the /backup/system/logs/warnings.txt to /logs/archive",{"entities":[(0,2,"ACTION"),(7,39,"FILE"),(40,56,"DESTINATION")]}),("c d:/workspace/models/model_weights.h5 to /resources/training",{"entities":[(0,1,"ACTION"),(2,38,"FILE"),(39,61,"DESTINATION")]}),("move the c:/home/documents/meeting/minutes.docx to /reports/archive",{"entities":[(0,4,"ACTION"),(9,47,"FILE"),(48,67,"DESTINATION")]}),("cp the /users/admin/photos/family.jpg to /gallery/family",{"entities":[(0,2,"ACTION"),(7,37,"FILE"),(38,56,"DESTINATION")]}),("c temp/logs/error.log to /backup/logs",{"entities":[(0,1,"ACTION"),(2,21,"FILE"),(22,37,"DESTINATION")]}),("copy the c:/resources/training/labels.json to /datasets/final",{"entities":[(0,4,"ACTION"),(9,42,"FILE"),(43,61,"DESTINATION")]}),("cp the /configs/templates/template2.docx to /library/templates",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,62,"DESTINATION")]}),("m d:/users/admin/projects/example_project to /resources/examples",{"entities":[(0,1,"ACTION"),(2,41,"FOLDER"),(42,64,"DESTINATION")]}),("copy the c:/images/profile.png to /gallery/profiles",{"entities":[(0,4,"ACTION"),(9,30,"FILE"),(31,51,"DESTINATION")]}),("copy the c:/downloads/videos/tutorial.mp4 to /media/tutorials",{"entities":[(0,4,"ACTION"),(9,41,"FILE"),(42,61,"DESTINATION")]}),("cp the /videos/movies/drama.mp4 to /media/films",{"entities":[(0,2,"ACTION"),(7,31,"FILE"),(32,47,"DESTINATION")]}),("m temp/data/analysis.txt to /resources/archives",{"entities":[(0,1,"ACTION"),(2,24,"FILE"),(25,47,"DESTINATION")]}),("copy the c:/configs/server/backup.xml to /configs/backup",{"entities":[(0,4,"ACTION"),(9,37,"FILE"),(38,56,"DESTINATION")]}),("cp the /backup/system/logs/critical_errors.txt to /logs/archive",{"entities":[(0,2,"ACTION"),(7,46,"FILE"),(47,63,"DESTINATION")]}),("m d:/workspace/models/model_summary.h5 to /resources/training",{"entities":[(0,1,"ACTION"),(2,38,"FILE"),(39,61,"DESTINATION")]}),("copy the c:/home/documents/presentations/slides.pptx to /reports/archive",{"entities":[(0,4,"ACTION"),(9,52,"FILE"),(53,72,"DESTINATION")]}),("cp the /users/admin/photos/holiday.jpg to /gallery/holidays",{"entities":[(0,2,"ACTION"),(7,38,"FILE"),(39,59,"DESTINATION")]}),("m temp/logs/access.log to /backup/logs",{"entities":[(0,1,"ACTION"),(2,22,"FILE"),(23,38,"DESTINATION")]}),("copy the c:/resources/training/metadata.json to /datasets/final",{"entities":[(0,4,"ACTION"),(9,44,"FILE"),(45,63,"DESTINATION")]}),("cp the /configs/templates/template3.docx to /library/templates",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,62,"DESTINATION")]}),("m d:/users/admin/projects/demo_project to /resources/examples",{"entities":[(0,1,"ACTION"),(2,38,"FOLDER"),(39,61,"DESTINATION")]}),("copy the c:/images/thumbnail.png to /gallery/thumbnails",{"entities":[(0,4,"ACTION"),(9,32,"FILE"),(33,55,"DESTINATION")]}),("copy the c:/downloads/books/novel.pdf to /documents/ebooks",{"entities":[(0,4,"ACTION"),(9,37,"FILE"),(38,58,"DESTINATION")]}),("cp the /videos/series/comedy.mp4 to /media/series",{"entities":[(0,2,"ACTION"),(7,32,"FILE"),(33,49,"DESTINATION")]}),("m temp/data/report.txt to /resources/archives",{"entities":[(0,1,"ACTION"),(2,22,"FILE"),(23,45,"DESTINATION")]}),("copy the c:/configs/app/settings.yaml to /configs/backup",{"entities":[(0,4,"ACTION"),(9,37,"FILE"),(38,56,"DESTINATION")]}),("cp the /backup/system/logs/info.txt to /logs/archive",{"entities":[(0,2,"ACTION"),(7,35,"FILE"),(36,52,"DESTINATION")]}),("m d:/workspace/models/model_performance.h5 to /resources/training",{"entities":[(0,1,"ACTION"),(2,42,"FILE"),(43,65,"DESTINATION")]}),("copy the c:/home/documents/notes/meeting_notes.txt to /reports/archive",{"entities":[(0,4,"ACTION"),(9,50,"FILE"),(51,70,"DESTINATION")]}),("cp the /users/admin/photos/landscape.jpg to /gallery/landscapes",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,63,"DESTINATION")]}),("m temp/logs/debug.log to /backup/logs",{"entities":[(0,1,"ACTION"),(2,21,"FILE"),(22,37,"DESTINATION")]}),("copy the c:/resources/training/annotations.json to /datasets/final",{"entities":[(0,4,"ACTION"),(9,47,"FILE"),(48,66,"DESTINATION")]}),("cp the /configs/templates/template4.docx to /library/templates",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,62,"DESTINATION")]}),("m d:/users/admin/projects/sample_project_v2 to /resources/examples",{"entities":[(0,1,"ACTION"),(2,43,"FOLDER"),(44,66,"DESTINATION")]}),("copy the c:/images/banner.png to /gallery/banners",{"entities":[(0,4,"ACTION"),(9,29,"FILE"),(30,49,"DESTINATION")]}),("copy the c:/media/music/track.mp3 to /audio/collection",{"entities":[(0,4,"ACTION"),(9,33,"FILE"),(34,54,"DESTINATION")]}),("cp the /videos/movies/action.mp4 to /media/films",{"entities":[(0,2,"ACTION"),(7,32,"FILE"),(33,48,"DESTINATION")]}),("m temp/data/summary.txt to /resources/archives",{"entities":[(0,1,"ACTION"),(2,23,"FILE"),(24,46,"DESTINATION")]}),("copy the c:/configs/server/settings.xml to /configs/backup",{"entities":[(0,4,"ACTION"),(9,39,"FILE"),(40,58,"DESTINATION")]}),("cp the /backup/system/logs/errors.txt to /logs/archive",{"entities":[(0,2,"ACTION"),(7,37,"FILE"),(38,54,"DESTINATION")]}),("m d:/workspace/models/output.h5 to /resources/training",{"entities":[(0,1,"ACTION"),(2,31,"FILE"),(32,54,"DESTINATION")]}),("copy the c:/home/documents/reports/weekly.docx to /reports/archive",{"entities":[(0,4,"ACTION"),(9,46,"FILE"),(47,66,"DESTINATION")]}),("cp the /users/admin/photos/trip.jpg to /gallery/vacation",{"entities":[(0,2,"ACTION"),(7,35,"FILE"),(36,56,"DESTINATION")]}),("m temp/logs/system.log to /backup/logs",{"entities":[(0,1,"ACTION"),(2,22,"FILE"),(23,38,"DESTINATION")]}),("copy the c:/resources/training/data.json to /datasets/final",{"entities":[(0,4,"ACTION"),(9,40,"FILE"),(41,59,"DESTINATION")]}),("cp the /configs/templates/template1.docx to /library/templates",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,62,"DESTINATION")]}),("m d:/users/admin/projects/sample to /resources/examples",{"entities":[(0,1,"ACTION"),(2,32,"FOLDER"),(33,55,"DESTINATION")]}),("copy the c:/images/screenshot.png to /gallery/screenshots",{"entities":[(0,4,"ACTION"),(9,33,"FILE"),(34,57,"DESTINATION")]}),("copy the c:/downloads/music/album.zip to /audio/archives",{"entities":[(0,4,"ACTION"),(9,37,"FILE"),(38,56,"DESTINATION")]}),("cp the /videos/documentaries/nature.mp4 to /media/documentaries",{"entities":[(0,2,"ACTION"),(3,39,"FILE"),(40,63,"DESTINATION")]}),("m temp/data/overview.txt to /resources/archives",{"entities":[(0,1,"ACTION"),(2,24,"FILE"),(25,47,"DESTINATION")]}),("copy the c:/configs/app/config.json to /configs/backup",{"entities":[(0,4,"ACTION"),(9,35,"FILE"),(36,54,"DESTINATION")]}),("cp the /backup/system/logs/warnings.txt to /logs/archive",{"entities":[(0,2,"ACTION"),(7,39,"FILE"),(40,56,"DESTINATION")]}),("m d:/workspace/models/model_weights.h5 to /resources/training",{"entities":[(0,1,"ACTION"),(2,38,"FILE"),(39,61,"DESTINATION")]}),("copy the c:/home/documents/meeting/minutes.docx to /reports/archive",{"entities":[(0,4,"ACTION"),(9,47,"FILE"),(48,67,"DESTINATION")]}),("cp the /users/admin/photos/family.jpg to /gallery/family",{"entities":[(0,2,"ACTION"),(7,37,"FILE"),(38,56,"DESTINATION")]}),("m temp/logs/error.log to /backup/logs",{"entities":[(0,1,"ACTION"),(2,21,"FILE"),(22,37,"DESTINATION")]}),("copy the c:/resources/training/labels.json to /datasets/final",{"entities":[(0,4,"ACTION"),(9,42,"FILE"),(43,61,"DESTINATION")]}),("cp the /configs/templates/template2.docx to /library/templates",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,62,"DESTINATION")]}),("m d:/users/admin/projects/example_project to /resources/examples",{"entities":[(0,1,"ACTION"),(2,41,"FOLDER"),(42,64,"DESTINATION")]}),("copy the c:/images/profile.png to /gallery/profiles",{"entities":[(0,4,"ACTION"),(9,30,"FILE"),(31,51,"DESTINATION")]}),("copy the c:/downloads/videos/tutorial.mp4 to /media/tutorials",{"entities":[(0,4,"ACTION"),(9,41,"FILE"),(42,61,"DESTINATION")]}),("cp the /videos/movies/drama.mp4 to /media/films",{"entities":[(0,2,"ACTION"),(7,31,"FILE"),(32,47,"DESTINATION")]}),("m temp/data/analysis.txt to /resources/archives",{"entities":[(0,1,"ACTION"),(2,24,"FILE"),(25,47,"DESTINATION")]}),("copy the c:/configs/server/backup.xml to /configs/backup",{"entities":[(0,4,"ACTION"),(9,37,"FILE"),(38,56,"DESTINATION")]}),("cp the /backup/system/logs/critical_errors.txt to /logs/archive",{"entities":[(0,2,"ACTION"),(7,46,"FILE"),(47,63,"DESTINATION")]}),("m d:/workspace/models/model_summary.h5 to /resources/training",{"entities":[(0,1,"ACTION"),(2,38,"FILE"),(39,61,"DESTINATION")]}),("copy the c:/home/documents/presentations/slides.pptx to /reports/archive",{"entities":[(0,4,"ACTION"),(9,52,"FILE"),(53,72,"DESTINATION")]}),("c temp/logs/access.log to /backup/logs",{"entities":[(0,1,"ACTION"),(2,22,"FILE"),(23,38,"DESTINATION")]}),("copy the c:/resources/training/metadata.json to /datasets/final",{"entities":[(0,4,"ACTION"),(9,44,"FILE"),(45,63,"DESTINATION")]}),("mv the /configs/templates/template3.docx to /library/templates",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,62,"DESTINATION")]}),("copy the c:/images/thumbnail.png to /gallery/thumbnails",{"entities":[(0,4,"ACTION"),(9,32,"FILE"),(33,55,"DESTINATION")]}),("copy the c:/downloads/books/novel.pdf to /documents/ebooks",{"entities":[(0,4,"ACTION"),(9,37,"FILE"),(38,58,"DESTINATION")]}),("mv the /videos/series/comedy.mp4 to /media/series",{"entities":[(0,2,"ACTION"),(7,32,"FILE"),(33,49,"DESTINATION")]}),("c temp/data/report.txt to /resources/archives",{"entities":[(0,1,"ACTION"),(2,22,"FILE"),(23,45,"DESTINATION")]}),("copy the c:/configs/app/settings.yaml to /configs/backup",{"entities":[(0,4,"ACTION"),(9,37,"FILE"),(38,56,"DESTINATION")]}),("mv the /backup/system/logs/info.txt to /logs/archive",{"entities":[(0,2,"ACTION"),(7,35,"FILE"),(36,52,"DESTINATION")]}),("c d:/workspace/models/model_performance.h5 to /resources/training",{"entities":[(0,1,"ACTION"),(2,42,"FILE"),(43,65,"DESTINATION")]}),("copy the c:/home/documents/notes/meeting_notes.txt to /reports/archive",{"entities":[(0,4,"ACTION"),(9,50,"FILE"),(51,70,"DESTINATION")]}),("mv the /users/admin/photos/landscape.jpg to /gallery/landscapes",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,63,"DESTINATION")]}),("c temp/logs/debug.log to /backup/logs",{"entities":[(0,1,"ACTION"),(2,21,"FILE"),(22,37,"DESTINATION")]}),("copy the c:/resources/training/annotations.json to /datasets/final",{"entities":[(0,4,"ACTION"),(9,47,"FILE"),(48,66,"DESTINATION")]}),("mv the /configs/templates/template4.docx to /library/templates",{"entities":[(0,2,"ACTION"),(7,40,"FILE"),(41,62,"DESTINATION")]}),("c d:/users/admin/projects/sample_project_v2 to /resources/examples",{"entities":[(0,1,"ACTION"),(2,43,"FOLDER"),(44,66,"DESTINATION")]}),("copy the c:/images/banner.png to /gallery/banners",{"entities":[(0,4,"ACTION"),(9,29,"FILE"),(30,49,"DESTINATION")]}),("create the api/routes.js",{"entities":[(0,6,"ACTION"),(11,24,"FILE")]}),("mk main/settings/config.yaml",{"entities":[(0,2,"ACTION"),(3,28,"FILE")]}),("create the file report.docx",{"entities":[(0,6,"ACTION"),(11,27,"FILE")]}),("create the dashboard.html",{"entities":[(0,6,"ACTION"),(11,25,"FILE")]}),("mkdir /resources/deployment/scripts",{"entities":[(0,5,"ACTION"),(6,35,"FOLDER")]}),("create the app/configs/api_keys.env",{"entities":[(0,6,"ACTION"),(11,35,"FILE")]}),("create the index.php",{"entities":[(0,6,"ACTION"),(11,20,"FILE")]}),("mk /logs/access_logs.txt",{"entities":[(0,2,"ACTION"),(3,24,"FILE")]}),("create the file themes.xml",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("mkdir /backup/data/archives",{"entities":[(0,5,"ACTION"),(6,27,"FOLDER")]}),("make the bot/main.py",{"entities":[(0,4,"ACTION"),(9,20,"FILE")]}),("create the file inventory.csv",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("mk main/services/config.ini",{"entities":[(0,2,"ACTION"),(3,27,"FILE")]}),("create the index.css",{"entities":[(0,6,"ACTION"),(11,20,"FILE")]}),("mkdir /documents/presentations/slides",{"entities":[(0,5,"ACTION"),(6,37,"FOLDER")]}),("create the test_cases.spec.js",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("create the file database.db",{"entities":[(0,6,"ACTION"),(11,27,"FILE")]}),("mk /images/photos/snapshot.jpg",{"entities":[(0,2,"ACTION"),(3,30,"FILE")]}),("create the config/test_script.sh",{"entities":[(0,6,"ACTION"),(11,32,"FILE")]}),("create the main/index.html",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("mkdir /scripts/deployment/pipeline",{"entities":[(0,5,"ACTION"),(6,34,"FOLDER")]}),("create the auth/keys.pem",{"entities":[(0,6,"ACTION"),(11,24,"FILE")]}),("mk /configs/system/error_logs.log",{"entities":[(0,2,"ACTION"),(3,33,"FILE")]}),("make the main_script.pl",{"entities":[(0,4,"ACTION"),(9,23,"FILE")]}),("mkdir /projects/backend/models",{"entities":[(0,5,"ACTION"),(6,30,"FOLDER")]}),("create the app/data/config.toml",{"entities":[(0,6,"ACTION"),(11,31,"FILE")]}),("create the file schedule.xlsx",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("mk /docs/research/summary.pdf",{"entities":[(0,2,"ACTION"),(3,29,"FILE")]}),("create the theme.scss",{"entities":[(0,6,"ACTION"),(11,21,"FILE")]}),("create the file user_profile.json",{"entities":[(0,6,"ACTION"),(11,33,"FILE")]}),("mk the folder /configs/api_routes",{"entities":[(0,2,"ACTION"),(7,33,"FOLDER")]}),("mkdir /projects/frontend/components",{"entities":[(0,5,"ACTION"),(6,35,"FOLDER")]}),("create the file app.tsx",{"entities":[(0,6,"ACTION"),(11,23,"FILE")]}),("create the backend/database/schema.sql",{"entities":[(0,6,"ACTION"),(11,38,"FILE")]}),("mk /docs/manual/guide.pdf",{"entities":[(0,2,"ACTION"),(3,25,"FILE")]}),("create the file themes/settings.ini",{"entities":[(0,6,"ACTION"),(11,35,"FILE")]}),("mkdir /logs/server/errors.log",{"entities":[(0,5,"ACTION"),(6,29,"FILE")]}),("create the file output.log",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("create the config/prod.env",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("mk /resources/images/logo.svg",{"entities":[(0,2,"ACTION"),(3,29,"FILE")]}),("create the dashboard.vue",{"entities":[(0,6,"ACTION"),(11,24,"FILE")]}),("mkdir /archives/data_backup.zip",{"entities":[(0,5,"ACTION"),(6,31,"FILE")]}),("create the test_data/test_input.txt",{"entities":[(0,6,"ACTION"),(11,35,"FILE")]}),("create the file index.jsx",{"entities":[(0,6,"ACTION"),(11,25,"FILE")]}),("mk /configs/system/preferences.json",{"entities":[(0,2,"ACTION"),(3,35,"FILE")]}),("create the main/scripts/build.gradle",{"entities":[(0,6,"ACTION"),(11,36,"FILE")]}),("create the file template.docx",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("mk /reports/yearly/summary.xlsx",{"entities":[(0,2,"ACTION"),(3,31,"FILE")]}),("create the folder app/models.py",{"entities":[(0,6,"ACTION"),(11,31,"FILE")]}),("create the auth/credentials.pem",{"entities":[(0,6,"ACTION"),(11,31,"FILE")]}),("mkdir /projects/utils/helpers.rb",{"entities":[(0,5,"ACTION"),(6,32,"FILE")]}),("create the user_data/profile.xml",{"entities":[(0,6,"ACTION"),(11,32,"FILE")]}),("create the file network_config.ini",{"entities":[(0,6,"ACTION"),(11,34,"FILE")]}),("mk /resources/fonts/styles.otf",{"entities":[(0,2,"ACTION"),(3,30,"FILE")]}),("create the index.md",{"entities":[(0,6,"ACTION"),(11,19,"FILE")]}),("mkdir /projects/docs/tutorials.md",{"entities":[(0,5,"ACTION"),(6,33,"FILE")]}),("create the analytics/setup.py",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("create the backend/routes/api.yaml",{"entities":[(0,6,"ACTION"),(11,34,"FILE")]}),("mk /images/samples/image.png",{"entities":[(0,2,"ACTION"),(3,28,"FILE")]}),("create the output/reports/summary.csv",{"entities":[(0,6,"ACTION"),(11,37,"FILE")]}),("create the config/setup.bash",{"entities":[(0,6,"ACTION"),(11,28,"FILE")]}),("mkdir /resources/templates/template.html",{"entities":[(0,5,"ACTION"),(6,40,"FILE")]}),("create the main_script.dart",{"entities":[(0,6,"ACTION"),(11,27,"FILE")]}),("create the file video.mp4",{"entities":[(0,6,"ACTION"),(11,25,"FILE")]}),("mk /data/exports/export_data.json",{"entities":[(0,2,"ACTION"),(3,33,"FILE")]}),("create the project/settings.gradle",{"entities":[(0,6,"ACTION"),(11,34,"FILE")]}),("create the ui/component.stories.js",{"entities":[(0,6,"ACTION"),(11,34,"FILE")]}),("mkdir /configs/system_logs/log.txt",{"entities":[(0,5,"ACTION"),(6,34,"FILE")]}),("create the file archive.zip",{"entities":[(0,6,"ACTION"),(11,27,"FILE")]}),("create the documents/files/manual.txt",{"entities":[(0,6,"ACTION"),(11,37,"FILE")]}),("d /photos/travel",{"entities":[(0,1,"ACTION"),(2,16,"FOLDER")]}),("delete c:/images/landscapes/sunset.png",{"entities":[(0,6,"ACTION"),(7,38,"FILE")]}),("rm /videos/documentary/history.mp4",{"entities":[(0,2,"ACTION"),(3,34,"FILE")]}),("remove /docs/archive/old_reports.docx",{"entities":[(0,6,"ACTION"),(7,37,"FILE")]}),("del the /gallery/nature/forest.jpg",{"entities":[(0,3,"ACTION"),(8,34,"FILE")]}),("d /media/movies/action",{"entities":[(0,1,"ACTION"),(2,22,"FOLDER")]}),("delete c:/projects/data/dataset.csv",{"entities":[(0,6,"ACTION"),(7,35,"FILE")]}),("rm /backup/system/logs/errors.log",{"entities":[(0,2,"ACTION"),(3,33,"FILE")]}),("remove /configs/security/rules.yaml",{"entities":[(0,6,"ACTION"),(7,35,"FILE")]}),("del the /pictures/winter.jpg",{"entities":[(0,3,"ACTION"),(8,28,"FILE")]}),("d /media/music/classics",{"entities":[(0,1,"ACTION"),(2,23,"FOLDER")]}),("delete c:/temp/logs/debug.log",{"entities":[(0,6,"ACTION"),(7,29,"FILE")]}),("rm /resources/training/models/output.h5",{"entities":[(0,2,"ACTION"),(3,39,"FILE")]}),("remove /configs/network/settings.json",{"entities":[(0,6,"ACTION"),(7,37,"FILE")]}),("del the /images/vacation/mountains.png",{"entities":[(0,3,"ACTION"),(8,38,"FILE")]}),("d /gallery/photos/landscapes",{"entities":[(0,1,"ACTION"),(2,28,"FOLDER")]}),("delete c:/movies/genres/scifi.mkv",{"entities":[(0,6,"ACTION"),(7,33,"FILE")]}),("rm /docs/templates/template1.docx",{"entities":[(0,2,"ACTION"),(3,33,"FILE")]}),("remove /library/books/classics.pdf",{"entities":[(0,6,"ACTION"),(7,34,"FILE")]}),("del the /pictures/flowers.jpg",{"entities":[(0,3,"ACTION"),(8,29,"FILE")]}),("d /media/videos/tutorials",{"entities":[(0,1,"ACTION"),(2,25,"FOLDER")]}),("delete c:/home/notes/todo.txt",{"entities":[(0,6,"ACTION"),(7,29,"FILE")]}),("rm /projects/code/unused_script.py",{"entities":[(0,2,"ACTION"),(3,34,"FILE")]}),("remove /pictures/trip/beach.jpg",{"entities":[(0,6,"ACTION"),(7,31,"FILE")]}),("del the /music/genres/blues",{"entities":[(0,3,"ACTION"),(8,27,"FOLDER")]}),("d /photos/nature/lake.jpg",{"entities":[(0,1,"ACTION"),(2,25,"FILE")]}),("find 'email' in C:/Users/Admin/Documents/user_data.json",{"entities":[(0,4,"ACTION"),(5,12,"TEXT"),(16,55,"FILE")]}),("where 'password' in D:/Data/security/credentials.csv",{"entities":[(0,5,"ACTION"),(6,16,"TEXT"),(20,52,"FILE")]}),("search 'url' in C:/System/configurations/web_config.json",{"entities":[(0,6,"ACTION"),(7,12,"TEXT"),(16,56,"FILE")]}),("find 'debug' in /Network/settings/server_CANNEL.yaml",{"entities":[(0,4,"ACTION"),(5,12,"TEXT"),(16,52,"FILE")]}),("where 'key' in C:/Logs/access_logs.log",{"entities":[(0,5,"ACTION"),(6,11,"TEXT"),(15,38,"FILE")]}),("search the 'timeout' in /Projects/logs/error.log",{"entities":[(0,6,"ACTION"),(11,20,"TEXT"),(24,48,"FILE")]}),("find 'database' in C:/Users/Public/Documents/config.db",{"entities":[(0,4,"ACTION"),(5,15,"TEXT"),(19,54,"FILE")]}),("where 'server' in /Configs/cloud/server_details.yaml",{"entities":[(0,5,"ACTION"),(6,14,"TEXT"),(18,52,"FILE")]}),("search 'cache' in C:/ProgramData/settings/cache_config.ini",{"entities":[(0,6,"ACTION"),(7,14,"TEXT"),(18,58,"FILE")]}),("find 'timeout' in /Configs/network/proxy.json",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,45,"FILE")]}),("where 'logfile' in C:/Users/Admin/Downloads/debug_logs.log",{"entities":[(0,5,"ACTION"),(6,15,"TEXT"),(19,58,"FILE")]}),("search the 'theme' in /Configs/app/ui_preferences.json",{"entities":[(0,6,"ACTION"),(11,18,"TEXT"),(22,54,"FILE")]}),("find 'region' in C:/System/locale/settings.json",{"entities":[(0,4,"ACTION"),(5,13,"TEXT"),(17,47,"FILE")]}),("where 'session_id' in /Configs/api/session_data.yaml",{"entities":[(0,5,"ACTION"),(6,18,"TEXT"),(22,52,"FILE")]}),("search 'admin' in C:/Users/Admin/AppData/temp/cache.json",{"entities":[(0,6,"ACTION"),(7,14,"TEXT"),(18,56,"FILE")]}),("find 'router' in C:/Network/devices/router_settings.ini",{"entities":[(0,4,"ACTION"),(5,13,"TEXT"),(17,55,"FILE")]}),("where 'queue' in /Projects/System/process_queues.yaml",{"entities":[(0,5,"ACTION"),(6,13,"TEXT"),(17,53,"FILE")]}),("search 'disk' in C:/System/storage/disk_config.ini",{"entities":[(0,6,"ACTION"),(7,13,"TEXT"),(17,50,"FILE")]}),("find 'gateway' in /Network/firewall/gateway_config.json",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,55,"FILE")]}),("where 'session_token' in C:/Users/Admin/Documents/session_data.json",{"entities":[(0,5,"ACTION"),(6,21,"TEXT"),(25,67,"FILE")]}),("search 'file' in D:/Work/docs/config.xml",{"entities":[(0,6,"ACTION"),(7,13,"TEXT"),(17,40,"FILE")]}),("find 'root' in /Configs/webapp/root_settings.yaml",{"entities":[(0,4,"ACTION"),(5,11,"TEXT"),(15,49,"FILE")]}),("where 'directory' in C:/System/settings/directories.json",{"entities":[(0,5,"ACTION"),(6,17,"TEXT"),(21,56,"FILE")]}),("search the 'access' in /Work/settings/access_rules.yaml",{"entities":[(0,6,"ACTION"),(11,19,"TEXT"),(23,55,"FILE")]}),("find 'policy' in C:/Configs/security/policies.json",{"entities":[(0,4,"ACTION"),(5,13,"TEXT"),(17,50,"FILE")]}),("where 'user_id' in /Projects/WebApp/config/user_settings.yaml",{"entities":[(0,5,"ACTION"),(6,15,"TEXT"),(19,61,"FILE")]}),("search 'path' in D:/Network/settings/routes.ini",{"entities":[(0,6,"ACTION"),(7,13,"TEXT"),(17,47,"FILE")]}),("find 'address' in /System/network/address_config.json",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,53,"FILE")]}),("where 'type' in C:/Logs/application_logs.log",{"entities":[(0,5,"ACTION"),(6,12,"TEXT"),(16,44,"FILE")]}),("search the 'status' in /Configs/logs/status_logs.yaml",{"entities":[(0,6,"ACTION"),(11,19,"TEXT"),(23,53,"FILE")]}),("copy the c:/media/movies/comedy.avi to /media/films",{"entities":[(0,4,"ACTION"),(9,35,"FILE"),(36,51,"DESTINATION")]}),("mv the /resources/data/input.csv to /datasets/input",{"entities":[(0,2,"ACTION"),(7,32,"FILE"),(33,51,"DESTINATION")]}),("c d:/workspace/scripts/main.py to /resources/development",{"entities":[(0,1,"ACTION"),(2,30,"FILE"),(31,56,"DESTINATION")]}),("m the /pictures/winter.jpg to /gallery",{"entities":[(0,1,"ACTION"),(6,26,"FILE"),(27,38,"DESTINATION")]}),("m the /videos/drama.mp4 to /media/movies",{"entities":[(0,1,"ACTION"),(6,23,"FILE"),(24,40,"DESTINATION")]}),("mv the /images/spring.jpg to /photos/nature",{"entities":[(0,2,"ACTION"),(7,25,"FILE"),(26,43,"DESTINATION")]}),("move the c:/documents/project.docx to /backup",{"entities":[(0,4,"ACTION"),(9,34,"FILE"),(35,45,"DESTINATION")]}),("m the /movies/comedy.mp4 to /media/films",{"entities":[(0,1,"ACTION"),(6,24,"FILE"),(25,40,"DESTINATION")]}),("mv the /images/sunset.png to /gallery",{"entities":[(0,2,"ACTION"),(7,25,"FILE"),(26,37,"DESTINATION")]}),("m the /documents/notes.txt to /resources",{"entities":[(0,1,"ACTION"),(6,26,"FILE"),(27,40,"DESTINATION")]}),("move the c:/home/reports/weekly.xlsx to /documents",{"entities":[(0,4,"ACTION"),(9,36,"FILE"),(37,50,"DESTINATION")]}),("m the /pictures/beach.jpg to /gallery",{"entities":[(0,1,"ACTION"),(6,25,"FILE"),(26,37,"DESTINATION")]}),("m the /tutorials/data_science.mp4 to /media",{"entities":[(0,1,"ACTION"),(6,33,"FILE"),(34,43,"DESTINATION")]}),("mv the /pictures/mountains.jpg to /photos/travel",{"entities":[(0,2,"ACTION"),(7,30,"FILE"),(31,48,"DESTINATION")]}),("move the c:/media/music/track.mp3 to /audio/songs",{"entities":[(0,4,"ACTION"),(9,33,"FILE"),(34,49,"DESTINATION")]}),("m the /movies/horror.mp4 to /media/films",{"entities":[(0,1,"ACTION"),(6,24,"FILE"),(25,40,"DESTINATION")]}),("mv the /images/lake.jpg to /photos/nature",{"entities":[(0,2,"ACTION"),(7,23,"FILE"),(24,41,"DESTINATION")]}),("move the c:/projects/code/main.py to /development",{"entities":[(0,4,"ACTION"),(9,33,"FILE"),(34,49,"DESTINATION")]}),("m the /pictures/cityscape.jpg to /gallery",{"entities":[(0,1,"ACTION"),(6,29,"FILE"),(30,41,"DESTINATION")]}),("m the /videos/documentary.mp4 to /media/films",{"entities":[(0,1,"ACTION"),(6,29,"FILE"),(30,45,"DESTINATION")]}),("mv the /pictures/flowers.jpg to /photos/nature",{"entities":[(0,2,"ACTION"),(7,28,"FILE"),(29,46,"DESTINATION")]}),("move the c:/home/scripts/setup.sh to /configs",{"entities":[(0,4,"ACTION"),(9,33,"FILE"),(34,45,"DESTINATION")]}),("m the /movies/romance.mp4 to /media/movies",{"entities":[(0,1,"ACTION"),(6,25,"FILE"),(26,42,"DESTINATION")]}),("mv the /images/forest.png to /gallery",{"entities":[(0,2,"ACTION"),(7,25,"FILE"),(26,37,"DESTINATION")]}),("move the c:/temp/data/input.csv to /resources",{"entities":[(0,4,"ACTION"),(9,31,"FILE"),(32,45,"DESTINATION")]}),("find 'debug' in /Network/settings/server_config.yaml ",{"entities":[(0,4,"ACTION"),(5,12,"TEXT"),(16,52,"FILE")]}),("where 'key' in C:/Logs/access_logs.log ",{"entities":[(0,5,"ACTION"),(6,11,"TEXT"),(15,38,"FILE")]}),("search the 'timeout' in /Projects/logs/error.log ",{"entities":[(0,6,"ACTION"),(11,20,"TEXT"),(24,48,"FILE")]}),("find 'database' in C:/Users/Public/Documents/config.db ",{"entities":[(0,4,"ACTION"),(5,15,"TEXT"),(19,54,"FILE")]}),("where 'server' in /Configs/cloud/server_details.yaml ",{"entities":[(0,5,"ACTION"),(6,14,"TEXT"),(18,52,"FILE")]}),("search 'cache' in C:/ProgramData/settings/cache_config.ini ",{"entities":[(0,6,"ACTION"),(7,14,"TEXT"),(18,58,"FILE")]}),("find 'timeout' in /Configs/network/proxy.json ",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,45,"FILE")]}),("where 'logfile' in C:/Users/Admin/Downloads/debug_logs.log ",{"entities":[(0,5,"ACTION"),(6,15,"TEXT"),(19,58,"FILE")]}),("search the 'theme' in /Configs/app/ui_preferences.json ",{"entities":[(0,6,"ACTION"),(11,18,"TEXT"),(22,54,"FILE")]}),("find 'region' in C:/System/locale/settings.json ",{"entities":[(0,4,"ACTION"),(5,13,"TEXT"),(17,47,"FILE")]}),("where 'session_id' in /Configs/api/session_data.yaml ",{"entities":[(0,5,"ACTION"),(6,18,"TEXT"),(22,52,"FILE")]}),("search 'admin' in C:/Users/Admin/AppData/temp/cache.json ",{"entities":[(0,6,"ACTION"),(7,14,"TEXT"),(18,56,"FILE")]}),("find 'router' in C:/Network/devices/router_settings.ini",{"entities":[(0,4,"ACTION"),(5,13,"TEXT"),(17,55,"FILE")]}),("find 'debug' in /Netilic/settings/server_config.yaml",{"entities":[(0,4,"ACTION"),(5,12,"TEXT"),(16,52,"FILE")]}),("where 'key' in C:/Logs/access_logs.log",{"entities":[(0,5,"ACTION"),(6,11,"TEXT"),(15,38,"FILE")]}),("search the 'timeout' in /Projects/logs/error.log",{"entities":[(0,6,"ACTION"),(11,20,"TEXT"),(24,48,"FILE")]}),("find 'database' in C:/Users/Public/Documents/config.db",{"entities":[(0,4,"ACTION"),(5,15,"TEXT"),(19,54,"FILE")]}),("where 'server' in /Configs/cloud/server_details.yaml",{"entities":[(0,5,"ACTION"),(6,14,"TEXT"),(18,52,"FILE")]}),("search 'cache' in C:/ProgramData/settings/cache_config.ini",{"entities":[(0,6,"ACTION"),(7,14,"TEXT"),(18,58,"FILE")]}),("find 'timeout' in /Configs/network/proxy.json",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,45,"FILE")]}),("where 'logfile' in C:/Users/Admin/Downloads/debug_logs.log",{"entities":[(0,5,"ACTION"),(6,15,"TEXT"),(19,58,"FILE")]}),("search the 'theme' in /Configs/app/ui_preferences.json",{"entities":[(0,6,"ACTION"),(11,18,"TEXT"),(22,54,"FILE")]}),("find 'region' in C:/System/locale/settings.json",{"entities":[(0,4,"ACTION"),(5,13,"TEXT"),(17,47,"FILE")]}),("where 'session_id' in /Configs/api/session_data.yaml",{"entities":[(0,5,"ACTION"),(6,18,"TEXT"),(22,52,"FILE")]}),("search 'admin' in C:/Users/Admin/AppData/temp/cache.json",{"entities":[(0,6,"ACTION"),(7,14,"TEXT"),(18,56,"FILE")]}),("find 'router' in C:/Network/devices/router_settings.ini",{"entities":[(0,4,"ACTION"),(5,13,"TEXT"),(17,55,"FILE")]}),("search 'port' in C:/System/configurations/network_config.json",{"entities":[(0,6,"ACTION"),(7,13,"TEXT"),(17,61,"FILE")]}),("find 'version' in /Network/settings/app_config.yaml",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,51,"FILE")]}),("where 'token' in C:/Logs/authentication_logs.log",{"entities":[(0,5,"ACTION"),(6,13,"TEXT"),(17,48,"FILE")]}),("search the 'retry' in /Projects/logs/connection.log",{"entities":[(0,6,"ACTION"),(11,18,"TEXT"),(22,51,"FILE")]}),("find 'username' in C:/Users/Public/Documents/user_data.db",{"entities":[(0,4,"ACTION"),(5,15,"TEXT"),(19,57,"FILE")]}),("where 'host' in /Configs/cloud/host_details.yaml",{"entities":[(0,5,"ACTION"),(6,12,"TEXT"),(16,48,"FILE")]}),("search 'timeout' in C:/ProgramData/settings/timeout_config.ini",{"entities":[(0,6,"ACTION"),(7,16,"TEXT"),(20,62,"FILE")]}),("find 'path' in /Configs/network/path.json",{"entities":[(0,4,"ACTION"),(5,11,"TEXT"),(15,41,"FILE")]}),("where 'error' in C:/Users/Admin/Downloads/error_logs.log",{"entities":[(0,5,"ACTION"),(6,13,"TEXT"),(17,56,"FILE")]}),("search the 'layout' in /Configs/app/layout_preferences.json",{"entities":[(0,6,"ACTION"),(11,19,"TEXT"),(23,59,"FILE")]}),("find 'country' in C:/System/locale/country_settings.json",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,56,"FILE")]}),("where 'session' in /Configs/api/session_info.yaml",{"entities":[(0,5,"ACTION"),(6,15,"TEXT"),(19,49,"FILE")]}),("search 'cache_size' in C:/Users/Admin/AppData/temp/cache_settings.json",{"entities":[(0,6,"ACTION"),(7,19,"TEXT"),(23,70,"FILE")]}),("find 'gateway' in C:/Network/devices/gateway_settings.ini",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,57,"FILE")]}),("search 'protocol' in C:/System/configurations/protocol_config.json",{"entities":[(0,6,"ACTION"),(7,17,"TEXT"),(21,66,"FILE")]}),("find 'timeout' in /Network/settings/timeout_config.yaml",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,55,"FILE")]}),("where 'client_id' in C:/Logs/client_logs.log",{"entities":[(0,5,"ACTION"),(6,17,"TEXT"),(21,44,"FILE")]}),("search the 'version' in /Projects/logs/version.log",{"entities":[(0,6,"ACTION"),(11,20,"TEXT"),(24,50,"FILE")]}),("find 'database_url' in C:/Users/Public/Documents/db_config.db",{"entities":[(0,4,"ACTION"),(5,19,"TEXT"),(23,61,"FILE")]}),("where 'service' in /Configs/cloud/service_details.yaml",{"entities":[(0,5,"ACTION"),(6,15,"TEXT"),(19,54,"FILE")]}),("search 'max_connections' in C:/ProgramData/settings/connection_config.ini",{"entities":[(0,6,"ACTION"),(7,24,"TEXT"),(28,73,"FILE")]}),("find 'timeout' in /Configs/network/timeout.json",{"entities":[(0,4,"ACTION"),(5,14,"TEXT"),(18,47,"FILE")]}),("where 'log_level' in C:/Users/Admin/Downloads/log_level.log",{"entities":[(0,5,"ACTION"),(6,17,"TEXT"),(21,59,"FILE")]}),("search the 'color_scheme' in /Configs/app/color_preferences.json",{"entities":[(0,6,"ACTION"),(11,25,"TEXT"),(29,64,"FILE")]}),("find 'language' in C:/System/locale/language_settings.json",{"entities":[(0,4,"ACTION"),(5,15,"TEXT"),(19,58,"FILE")]}),("where 'session_key' in /Configs/api/session_keys.yaml",{"entities":[(0,5,"ACTION"),(6,19,"TEXT"),(23,53,"FILE")]}),("search 'cache_timeout' in C:/Users/Admin/AppData/temp/cache_timeout.json",{"entities":[(0,6,"ACTION"),(7,22,"TEXT"),(26,72,"FILE")]}),("find 'dns' in C:/Network/devices/dns_settings.ini",{"entities":[(0,4,"ACTION"),(5,10,"TEXT"),(14,49,"FILE")]}),("m the /tutorials/python_basics.mp4 to /media",{"entities":[(0,1,"ACTION"),(6,34,"FILE"),(35,44,"DESTINATION")]}),("mv the /pictures/desert.jpg to /gallery",{"entities":[(0,2,"ACTION"),(7,27,"FILE"),(28,39,"DESTINATION")]}),("move the c:/projects/design/mockup.psd to /designs",{"entities":[(0,4,"ACTION"),(9,38,"FILE"),(39,50,"DESTINATION")]}),("m the /movies/adventure.mp4 to /media/films",{"entities":[(0,1,"ACTION"),(6,27,"FILE"),(28,43,"DESTINATION")]}),("mv the /images/waterfall.jpg to /photos/nature",{"entities":[(0,2,"ACTION"),(7,28,"FILE"),(29,46,"DESTINATION")]}),("move the c:/home/logs/system.log to /backup/logs",{"entities":[(0,4,"ACTION"),(9,32,"FILE"),(33,48,"DESTINATION")]}),("m the /videos/scifi.mp4 to /media/films",{"entities":[(0,1,"ACTION"),(6,23,"FILE"),(24,39,"DESTINATION")]}),("mv the /pictures/rain.jpg to /photos/travel",{"entities":[(0,2,"ACTION"),(7,25,"FILE"),(26,43,"DESTINATION")]}),("uz /backup/logs/system_errors.log",{"entities":[(0,2,"ACTION"),(3,33,"FILE")]}),("zip the file report.docx",{"entities":[(0,3,"ACTION"),(13,24,"FILE")]}),("z the folder /images/winter",{"entities":[(0,1,"ACTION"),(13,27,"FOLDER")]}),("compress folder /users/guest/downloads",{"entities":[(0,8,"ACTION"),(16,38,"FOLDER")]}),("unzip /archives/pictures.zip",{"entities":[(0,5,"ACTION"),(6,28,"FILE")]}),("extract /projects/source/main.cpp",{"entities":[(0,7,"ACTION"),(8,33,"FILE")]}),("uz /configs/archive/system_config.json",{"entities":[(0,2,"ACTION"),(3,38,"FILE")]}),("zip the file project_plan.pdf",{"entities":[(0,3,"ACTION"),(8,29,"FILE")]}),("z the folder /library/books/classics",{"entities":[(0,1,"ACTION"),(13,36,"FOLDER")]}),("decompress folder /temp/cache",{"entities":[(0,10,"ACTION"),(18,29,"FOLDER")]}),("unzip /media/videos.zip",{"entities":[(0,5,"ACTION"),(6,23,"FILE")]}),("extract /projects/utils/helper.py",{"entities":[(0,7,"ACTION"),(8,33,"FILE")]}),("uz /docs/reports/financial_summary.docx",{"entities":[(0,2,"ACTION"),(3,39,"FILE")]}),("zip the file analysis_results.csv",{"entities":[(0,3,"ACTION"),(13,33,"FILE")]}),("z the folder /media/photos/nature",{"entities":[(0,1,"ACTION"),(13,33,"FOLDER")]}),("compress folder /admin/files",{"entities":[(0,8,"ACTION"),(16,28,"FOLDER")]}),("unzip /archives/backup.zip",{"entities":[(0,5,"ACTION"),(6,26,"FILE")]}),("extract /projects/tools/utility.js",{"entities":[(0,7,"ACTION"),(8,34,"FILE")]}),("uz /files/backup/settings.xml",{"entities":[(0,2,"ACTION"),(3,29,"FILE")]}),("zip the file plan_summary.txt",{"entities":[(0,3,"ACTION"),(13,29,"FILE")]}),("z the folder /users/admin/music",{"entities":[(0,1,"ACTION"),(13,31,"FOLDER")]}),("compress folder /media/resources/assets",{"entities":[(0,8,"ACTION"),(16,39,"FOLDER")]}),("unzip /downloads/applications.zip",{"entities":[(0,5,"ACTION"),(6,33,"FILE")]}),("extract /temp/files/document.pdf",{"entities":[(0,7,"ACTION"),(8,32,"FILE")]}),("uz /configs/system/setup.yaml",{"entities":[(0,2,"ACTION"),(3,29,"FILE")]}),("zip the file work_schedule.docx",{"entities":[(0,3,"ACTION"),(13,31,"FILE")]}),("z the folder /pictures/summer",{"entities":[(0,1,"ACTION"),(13,29,"FOLDER")]}),("compress folder /projects/demo",{"entities":[(0,8,"ACTION"),(16,30,"FOLDER")]}),("unzip /media/data.zip",{"entities":[(0,5,"ACTION"),(6,21,"FILE")]}),("extract /docs/templates/template.docx",{"entities":[(0,7,"ACTION"),(8,37,"FILE")]}),("uz /configs/preferences/config.json",{"entities":[(0,2,"ACTION"),(3,35,"FILE")]}),("create the app.js",{"entities":[(0,6,"ACTION"),(11,17,"FILE")]}),("mk the file styles.scss",{"entities":[(0,2,"ACTION"),(12,23,"FILE")]}),("mkdir /configs/security",{"entities":[(0,5,"ACTION"),(6,23,"FOLDER")]}),("create the app.js",{"entities":[(0,6,"ACTION"),(11,17,"FILE")]}),("make script.py",{"entities":[(0,4,"ACTION"),(5,14,"FILE")]}),("create the main/configs/database",{"entities":[(0,6,"ACTION"),(11,32,"FOLDER")]}),("create the main_script.java",{"entities":[(0,6,"ACTION"),(11,27,"FILE")]}),("create the index.html",{"entities":[(0,6,"ACTION"),(11,21,"FILE")]}),("mk the file config.json",{"entities":[(0,2,"ACTION"),(12,23,"FILE")]}),("mkdir /assets/images",{"entities":[(0,5,"ACTION"),(6,20,"FOLDER")]}),("create the utils/helper.js",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("make data_processor.rb",{"entities":[(0,4,"ACTION"),(5,22,"FILE")]}),("create the styles/main.css",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("mk the file readme.md",{"entities":[(0,2,"ACTION"),(12,21,"FILE")]}),("create the api/routes.js",{"entities":[(0,6,"ACTION"),(11,24,"FILE")]}),("make app/config.yaml",{"entities":[(0,4,"ACTION"),(5,20,"FILE")]}),("create the main.py",{"entities":[(0,6,"ACTION"),(11,18,"FILE")]}),("mk the file script.sh",{"entities":[(0,2,"ACTION"),(12,21,"FILE")]}),("mkdir /logs/error",{"entities":[(0,5,"ACTION"),(6,17,"FOLDER")]}),("create the database/schema.sql",{"entities":[(0,6,"ACTION"),(11,30,"FILE")]}),("make server.go",{"entities":[(0,4,"ACTION"),(5,14,"FILE")]}),("create the config/settings.xml",{"entities":[(0,6,"ACTION"),(11,30,"FILE")]}),("create the user/profile.json",{"entities":[(0,6,"ACTION"),(11,28,"FILE")]}),("mk the file app.css",{"entities":[(0,2,"ACTION"),(12,19,"FILE")]}),("mkdir /src/components",{"entities":[(0,5,"ACTION"),(6,21,"FOLDER")]}),("create the services/authService.js",{"entities":[(0,6,"ACTION"),(11,34,"FILE")]}),("make data_analysis.py",{"entities":[(0,4,"ACTION"),(5,21,"FILE")]}),("create the assets/logo.png",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("mk the file .env",{"entities":[(0,2,"ACTION"),(12,16,"FILE")]}),("create the tests/test_app.js",{"entities":[(0,6,"ACTION"),(11,28,"FILE")]}),("make main.go",{"entities":[(0,4,"ACTION"),(5,12,"FILE")]}),("create the scripts/deploy.sh",{"entities":[(0,6,"ACTION"),(11,28,"FILE")]}),("mk the file package-lock.json",{"entities":[(0,2,"ACTION"),(12,29,"FILE")]}),("create the config/database.yml",{"entities":[(0,6,"ACTION"),(11,30,"FILE")]}),("mkdir /public/uploads",{"entities":[(0,5,"ACTION"),(6,21,"FOLDER")]}),("create the views/index.ejs",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("make app.js",{"entities":[(0,4,"ACTION"),(5,11,"FILE")]}),("create the middleware/logger.js",{"entities":[(0,6,"ACTION"),(11,31,"FILE")]}),("mk the file styles/variables.scss",{"entities":[(0,2,"ACTION"),(12,33,"FILE")]}),("create the controllers/userController.js",{"entities":[(0,6,"ACTION"),(11,40,"FILE")]}),("make app/config.json",{"entities":[(0,4,"ACTION"),(5,20,"FILE")]}),("create the models/userModel.js",{"entities":[(0,6,"ACTION"),(11,30,"FILE")]}),("mk the file README.md",{"entities":[(0,2,"ACTION"),(12,21,"FILE")]}),("create the migrations/20230101_create_users_table.js",{"entities":[(0,6,"ACTION"),(11,52,"FILE")]}),("make server.js",{"entities":[(0,4,"ACTION"),(5,14,"FILE")]}),("create the utils/fileUtils.py",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("mk the file .gitignore",{"entities":[(0,2,"ACTION"),(7,22,"FILE")]}),("create the assets/styles/main.scss",{"entities":[(0,6,"ACTION"),(11,34,"FILE")]}),("mkdir /data/backups",{"entities":[(0,5,"ACTION"),(6,19,"FOLDER")]}),("create the api/v1/user.js",{"entities":[(0,6,"ACTION"),(11,25,"FILE")]}),("make app/config.js",{"entities":[(0,4,"ACTION"),(5,18,"FILE")]}),("create the scripts/init.sh",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("mk the file styles/theme.css",{"entities":[(0,2,"ACTION"),(12,28,"FILE")]}),("create the tests/integration/test_user.js",{"entities":[(0,6,"ACTION"),(11,41,"FILE")]}),("make app.py",{"entities":[(0,4,"ACTION"),(5,11,"FILE")]}),("create the config/app_config.yaml",{"entities":[(0,6,"ACTION"),(11,33,"FILE")]}),("mk the file index.ts",{"entities":[(0,2,"ACTION"),(12,20,"FILE")]}),("create the services/emailService.js",{"entities":[(0,6,"ACTION"),(11,35,"FILE")]}),("make data_export.rb",{"entities":[(0,4,"ACTION"),(5,19,"FILE")]}),("create the assets/images/banner.jpg",{"entities":[(0,6,"ACTION"),(11,35,"FILE")]}),("mk the file package.json",{"entities":[(0,2,"ACTION"),(12,24,"FILE")]}),("create the logs/access.log",{"entities":[(0,6,"ACTION"),(11,26,"FILE")]}),("mkdir /src/hooks",{"entities":[(0,5,"ACTION"),(6,16,"FOLDER")]}),("create the components/Button.js",{"entities":[(0,6,"ACTION"),(11,31,"FILE")]}),("make app/configuration.json",{"entities":[(0,4,"ACTION"),(5,27,"FILE")]}),("create the scripts/cleanup.sh",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("mk the file styles/reset.css",{"entities":[(0,2,"ACTION"),(12,28,"FILE")]}),("create the views/dashboard.ejs",{"entities":[(0,6,"ACTION"),(11,30,"FILE")]}),("make server/config.js",{"entities":[(0,4,"ACTION"),(5,21,"FILE")]}),("create the utils/dateUtils.js",{"entities":[(0,6,"ACTION"),(11,29,"FILE")]}),("mk the file .babelrc",{"entities":[(0,2,"ACTION"),(12,20,"FILE")]}),("create the assets/fonts/Roboto-Regular.ttf",{"entities":[(0,6,"ACTION"),(11,42,"FILE")]}),("mkdir /src/reducers",{"entities":[(0,5,"ACTION"),(6,19,"FOLDER")]}),("create the reducers/userReducer.js",{"entities":[(0,6,"ACTION"),(11,34,"FILE")]}),("make app/main.go",{"entities":[(0,4,"ACTION"),(5,16,"FILE")]}),("create the tests/unit/test_userReducer.js",{"entities":[(0,6,"ACTION"),(11,41,"FILE")]}),("mk the file styles/animations.scss",{"entities":[(0,2,"ACTION"),(12,34,"FILE")]}),("create the api/v2/product.js",{"entities":[(0,6,"ACTION"),(11,28,"FILE")]}),("make app/config.yaml",{"entities":[(0,4,"ACTION"),(5,20,"FILE")]}),("create the scripts/start.sh",{"entities":[(0,6,"ACTION"),(11,27,"FILE")]}),("mk the file styles/layout.css",{"entities":[(0,2,"ACTION"),(12,29,"FILE")]}),("create the controllers/productController.js",{"entities":[(0,6,"ACTION"),(11,43,"FILE")]}),("make app.js",{"entities":[(0,4,"ACTION"),(5,11,"FILE")]}),("copy the c:/media/music/track1.mp3 to /audio/collection",{"entities":[(0,4,"ACTION"),(9,34,"FILE"),(35,55,"DESTINATION")]}),("copy the c:/media/music/track2.wav to /audio/collection",{"entities":[(0,4,"ACTION"),(9,34,"FILE"),(35,55,"DESTINATION")]}),("copy the c:/media/music/track3.flac to /audio/collection",{"entities":[(0,4,"ACTION"),(9,35,"FILE"),(36,56,"DESTINATION")]}),("copy the c:/media/music/track4.aac to /audio/collection",{"entities":[(0,4,"ACTION"),(9,34,"FILE"),(35,55,"DESTINATION")]}),("rn /logs/app_logs/errors.log to app_error_log.txt",{"entities":[(0,2,"ACTION"),(3,28,"FILE"),(29,49,"NEWNAME")]}),("rename the analytics/reports/summary.csv to yearly_summary.csv",{"entities":[(0,6,"ACTION"),(11,40,"FILE"),(41,62,"NEWNAME")]}),("rn /projects/frontend/styles.css as theme_styles.css",{"entities":[(0,2,"ACTION"),(3,32,"FILE"),(33,52,"NEWNAME")]}),("rename the snapshots/photo001.jpg to profile_picture.jpg",{"entities":[(0,6,"ACTION"),(11,33,"FILE"),(34,56,"NEWNAME")]}),("rn /configs/security/keys.pem to security_keys.pem",{"entities":[(0,2,"ACTION"),(3,29,"FILE"),(30,50,"NEWNAME")]}),("rename the api/documentation/openapi.yaml to api_docs.yaml",{"entities":[(0,6,"ACTION"),(11,41,"FILE"),(42,58,"NEWNAME")]}),("rn /scripts/deployment/deploy.sh as deployment_script.sh",{"entities":[(0,2,"ACTION"),(3,32,"FILE"),(33,56,"NEWNAME")]}),("rename the documents/archive/history.docx to historical_records.docx",{"entities":[(0,6,"ACTION"),(11,41,"FILE"),(42,68,"NEWNAME")]}),("rn /home/user/temp/file.tmp to temporary_file.tmp",{"entities":[(0,2,"ACTION"),(3,27,"FILE"),(28,49,"NEWNAME")]}),("rename the data/exports/report.json to export_data.json",{"entities":[(0,6,"ACTION"),(11,35,"FILE"),(36,55,"NEWNAME")]}),("rn /projects/utils/math.py as math_utilities.py",{"entities":[(0,2,"ACTION"),(3,26,"FILE"),(27,47,"NEWNAME")]}),("rename the resources/templates/base.html to base_template.html",{"entities":[(0,6,"ACTION"),(11,40,"FILE"),(41,62,"NEWNAME")]}),("rn /media/music/jazz.mp3 to relaxing_jazz.mp3",{"entities":[(0,2,"ACTION"),(3,24,"FILE"),(25,45,"NEWNAME")]}),("rename the logs/system/event.log to system_event_log.log",{"entities":[(0,6,"ACTION"),(11,32,"FILE"),(33,56,"NEWNAME")]}),("rn /configs/system/default.conf to default_config.conf",{"entities":[(0,2,"ACTION"),(3,31,"FILE"),(32,54,"NEWNAME")]}),("rename the folders/images/gallery to image_gallery",{"entities":[(0,6,"ACTION"),(11,33,"FOLDER"),(34,50,"NEWNAME")]}),("rn /projects/ml/models/model_v1.h5 to model_final.h5",{"entities":[(0,2,"ACTION"),(3,34,"FILE"),(35,52,"NEWNAME")]}),("rename the notes/docs/research.md to research_notes.md",{"entities":[(0,6,"ACTION"),(11,33,"FILE"),(34,54,"NEWNAME")]}),("rn /media/videos/trailer.mov to official_trailer.mov",{"entities":[(0,2,"ACTION"),(3,28,"FILE"),(29,52,"NEWNAME")]}),("rename the cache/system/temp.cache to temporary_cache.cache",{"entities":[(0,6,"ACTION"),(11,34,"FILE"),(35,59,"NEWNAME")]}),("rn /scripts/tests/unit_test.py as unit_tests.py",{"entities":[(0,2,"ACTION"),(3,30,"FILE"),(31,47,"NEWNAME")]}),("rename the backups/data_backup.zip to archive_backup.zip",{"entities":[(0,6,"ACTION"),(11,34,"FILE"),(35,56,"NEWNAME")]}),("rn /projects/backend/configs/settings.env as backend_env_settings.env",{"entities":[(0,2,"ACTION"),(3,41,"FILE"),(42,69,"NEWNAME")]}),("rename the user/admin/photos/profile.jpg to admin_profile_picture.jpg",{"entities":[(0,6,"ACTION"),(11,40,"FILE"),(41,69,"NEWNAME")]}),("rn /docs/projects/overview.pdf to project_overview.pdf",{"entities":[(0,2,"ACTION"),(3,30,"FILE"),(31,54,"NEWNAME")]}),("rename the server/logs/access.log to access_log_2024.log",{"entities":[(0,6,"ACTION"),(11,33,"FILE"),(34,56,"NEWNAME")]}),("rn /resources/fonts/main.ttf as primary_font.ttf",{"entities":[(0,2,"ACTION"),(3,28,"FILE"),(29,48,"NEWNAME")]}),("rename the configs/network/dns.yaml to dns_config.yaml",{"entities":[(0,6,"ACTION"),(11,35,"FILE"),(36,54,"NEWNAME")]}),("rn /archives/movies/classic.mp4 as classic_movie.mp4",{"entities":[(0,2,"ACTION"),(3,31,"FILE"),(32,52,"NEWNAME")]}),("rename the workspace/dev/config.js to development_config.js",{"entities":[(0,6,"ACTION"),(11,34,"FILE"),(35,59,"NEWNAME")]}),("rn /configs/api/endpoints.json as api_endpoints.json",{"entities":[(0,2,"ACTION"),(3,30,"FILE"),(31,52,"NEWNAME")]}),("rename the documents/files/manual.txt to man.txt",{"entities":[(0,6,"ACTION"),(11,37,"FILE"),(38,48,"NEWNAME")]}),("rn /home/user/hew.py to mainscript.py",{"entities":[(0,2,"ACTION"),(3,20,"FILE"),(21,37,"NEWNAME")]}),("rename the ui/component/header as head",{"entities":[(0,6,"ACTION"),(11,30,"FOLDER"),(31,38,"NEWNAME")]}),("rn videos/video.mp4 as important.mp4",{"entities":[(0,2,"ACTION"),(3,19,"FILE"),(20,36,"NEWNAME")]}),("rename the docs/guide/tutorial.md to tutorial_guide.md",{"entities":[(0,6,"ACTION"),(11,33,"FILE"),(34,54,"NEWNAME")]}),("rn /projects/codebase/script.js as app.js",{"entities":[(0,2,"ACTION"),(3,31,"FILE"),(32,41,"NEWNAME")]}),("rename the archive/data/report.xlsx to monthly_report.xlsx",{"entities":[(0,6,"ACTION"),(11,35,"FILE"),(36,58,"NEWNAME")]}),("rn /configs/settings/system.yaml as system_config.yaml",{"entities":[(0,2,"ACTION"),(3,32,"FILE"),(33,54,"NEWNAME")]}),("rename the folder /media/photos/holidays to vacation_photos",{"entities":[(0,6,"ACTION"),(18,40,"FOLDER"),(41,59,"NEWNAME")]}),("rn /temp/debug/logs.log to debug_log.txt",{"entities":[(0,2,"ACTION"),(3,23,"FILE"),(24,40,"NEWNAME")]}),("rename the analytics/models/predict.h5 to prediction_model.h5",{"entities":[(0,6,"ACTION"),(11,38,"FILE"),(39,61,"NEWNAME")]}),("rn /projects/frontend/index.html as main_page.html",{"entities":[(0,2,"ACTION"),(3,32,"FILE"),(33,50,"NEWNAME")]}),("rename the scripts/build/config.gradle to build_config.gradle",{"entities":[(0,6,"ACTION"),(11,38,"FILE"),(39,61,"NEWNAME")]}),("rn /users/admin/profile.jpg as user_profile.jpg",{"entities":[(0,2,"ACTION"),(3,27,"FILE"),(28,47,"NEWNAME")]}),("rename the logs/server/errors.log to error_logs.txt",{"entities":[(0,6,"ACTION"),(11,33,"FILE"),(34,51,"NEWNAME")]}),("rn /resources/images/banner.png as homepage_banner.png",{"entities":[(0,2,"ACTION"),(3,31,"FILE"),(32,54,"NEWNAME")]}),("rename the app/controllers/main.rb to main_controller.rb",{"entities":[(0,6,"ACTION"),(11,34,"FILE"),(35,56,"NEWNAME")]}),("rn /videos/short_clips/clip.mov as teaser.mov",{"entities":[(0,2,"ACTION"),(3,31,"FILE"),(32,45,"NEWNAME")]}),("rename the file archive/docs/history.pdf to history_archive.pdf",{"entities":[(0,6,"ACTION"),(16,40,"FILE"),(41,63,"NEWNAME")]}),("rn /configs/database/schema.sql as db_schema.sql",{"entities":[(0,2,"ACTION"),(3,31,"FILE"),(32,48,"NEWNAME")]}),("rename the audio/music/song.mp3 to classic_song.mp3",{"entities":[(0,6,"ACTION"),(11,31,"FILE"),(32,51,"NEWNAME")]}),("rn /projects/backend/utils/helpers.py as helper_functions.py",{"entities":[(0,2,"ACTION"),(3,37,"FILE"),(38,60,"NEWNAME")]}),("rename the snapshots/image001.png to cover_photo.png",{"entities":[(0,6,"NEWNAME"),(11,33,"FILE"),(34,52,"NEWNAME")]}),("rn /configs/api/routes.yaml to api_routes.yaml",{"entities":[(0,2,"ACTION"),(3,27,"FILE"),(28,46,"NEWNAME")]}),("rename the documents/resumes/john_doe.docx to resume_john.docx",{"entities":[(0,6,"ACTION"),(11,42,"FILE"),(43,62,"NEWNAME")]}),("rn /projects/backend/main.cpp as backend_main.cpp",{"entities":[(0,2,"ACTION"),(3,29,"FILE"),(30,49,"NEWNAME")]}),("rename the folder /projects/data/analytics to /projects/data_analysis  ",{"entities":[(0,6,"ACTION"),(18,42,"FOLDER"),(43,69,"NEWNAME")]}),("rn /media/photos/travel to /media/travel_photos  ",{"entities":[(0,2,"ACTION"),(3,23,"FOLDER"),(24,47,"NEWNAME")]}),("rename the directory /archives/logs/system_logs to /archives/system_logs_archive  ",{"entities":[(0,6,"ACTION"),(21,47,"FOLDER"),(48,80,"NEWNAME")]}),("rn /resources/templates/design to /resources/design_templates  ",{"entities":[(0,2,"ACTION"),(3,30,"FOLDER"),(31,61,"NEWNAME")]}),("rename the folder /users/admin/documents to /users/admin/docs_archive  ",{"entities":[(0,6,"ACTION"),(18,40,"FOLDER"),(41,69,"NEWNAME")]}),("rn /configs/api/settings to /configs/api_settings  ",{"entities":[(0,2,"ACTION"),(3,24,"FOLDER"),(25,49,"NEWNAME")]}),("rename the directory /snapshots/images/screenshots to /snapshots/screenshot_images  ",{"entities":[(0,6,"ACTION"),(21,50,"FOLDER"),(51,82,"NEWNAME")]}),("rn /backup/system to /backup/system_files  ",{"entities":[(0,2,"ACTION"),(3,17,"FOLDER"),(18,41,"NEWNAME")]}),("rename the folder /temp/files/cache to /temp/cache_files  ",{"entities":[(0,6,"ACTION"),(18,35,"FOLDER"),(36,56,"NEWNAME")]})]

# %%
import re
for text,annot in data:
    l,z=[],[]
    for start ,end , label in annot['entities']:
        if (label == 'DESTINATION'):
            file = text[start:end]
            print(None if ( (end == len(text)) and ('to ' in file) and ('.' not in file) and ('as ' not in file) and (file in text)) else f'{file} failed {text}')
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
for text,annot in data:
    doc = nlp(text=text)
    ent = []
    for start ,end , label in annot['entities']:
        span = doc.char_span(start,end,label=label)
        if span is None:
            print(f'skipping entities {text}')
            continue
        ent.append(span)
    doc.ents = ent
    docbin.add(doc)

docbin.to_disk('/home/balaji/MeineAI/MeineAI/trainedspacy/allnotseen.spacy')
# Out:
# skipping entities the /users/admin/photos/holiday.jpg to /gallery/holidays
# skipping entities the /users/admin/photos/holiday.jpg to /gallery/holidays
# skipping entities the /users/admin/photos/holiday.jpg to /gallery/holidays
# skipping entities c d:/users/admin/projects/demo_project to /resources/examples
